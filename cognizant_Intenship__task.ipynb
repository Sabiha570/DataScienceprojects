# %% [markdown]
# # New Section

# %% [markdown]
# # Import Corresponding Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load The Dataset

# %%
data = pd.read_csv("/content/sample_sales_data.csv")
data
# Out:
#       Unnamed: 0                        transaction_id         timestamp  \
# 0              0  a1c82654-c52c-45b3-8ce8-4c2a1efe63ed  02-03-2022 09:51
# 1              1  931ad550-09e8-4da6-beaa-8c9d17be9c60  06-03-2022 10:33
# 2              2  ae133534-6f61-4cd6-b6b8-d1c1d8d90aea  04-03-2022 17:20
# 3              3  157cebd9-aaf0-475d-8a11-7c8e0f5b76e4  02-03-2022 17:23
# 4              4  a81a6cd3-5e0c-44a2-826c-aea43e46c514  05-03-2022 14:32
# ...          ...                                   ...               ...
# 7824        7824  6c19b9fc-f86d-4526-9dfe-d8027a4d13ee  03-03-2022 18:22
# 7825        7825  1c69824b-e399-4b79-a5e7-04a3a7db0681  04-03-2022 19:14
# 7826        7826  79aee7d6-1405-4345-9a15-92541e9e1e74  03-03-2022 14:00
# 7827        7827  e5cc4f88-e5b7-4ad5-bc1b-12a828a14f55  04-03-2022 15:11
# 7828        7828  afd70b4f-ee21-402d-8d8f-0d9e13c2bea6  06-03-2022 13:50
#
#                                 product_id           category customer_type  \
# ...

# %% [markdown]
# # Explore The data

# %%
data.head()
# Out:
#    Unnamed: 0                        transaction_id         timestamp  \
# 0           0  a1c82654-c52c-45b3-8ce8-4c2a1efe63ed  02-03-2022 09:51
# 1           1  931ad550-09e8-4da6-beaa-8c9d17be9c60  06-03-2022 10:33
# 2           2  ae133534-6f61-4cd6-b6b8-d1c1d8d90aea  04-03-2022 17:20
# 3           3  157cebd9-aaf0-475d-8a11-7c8e0f5b76e4  02-03-2022 17:23
# 4           4  a81a6cd3-5e0c-44a2-826c-aea43e46c514  05-03-2022 14:32
#
#                              product_id category customer_type  unit_price  \
# 0  3bc6c1ea-0198-46de-9ffd-514ae3338713    fruit          gold        3.99
# 1  ad81b46c-bf38-41cf-9b54-5fe7f5eba93e    fruit      standard        3.99
# 2  7c55cbd4-f306-4c04-a030-628cbe7867c1    fruit       premium        0.19
# 3  80da8348-1707-403f-8be7-9e6deeccc883    fruit          gold        0.19
# 4  7f5e86e6-f06f-45f6-bf44-27b095c9ad1d    fruit         basic        4.49
#
#    quantity  total payment_type
# 0         2   7.98     e-wallet
# ...

# %%
data.tail()
# Out:
#       Unnamed: 0                        transaction_id         timestamp  \
# 7824        7824  6c19b9fc-f86d-4526-9dfe-d8027a4d13ee  03-03-2022 18:22
# 7825        7825  1c69824b-e399-4b79-a5e7-04a3a7db0681  04-03-2022 19:14
# 7826        7826  79aee7d6-1405-4345-9a15-92541e9e1e74  03-03-2022 14:00
# 7827        7827  e5cc4f88-e5b7-4ad5-bc1b-12a828a14f55  04-03-2022 15:11
# 7828        7828  afd70b4f-ee21-402d-8d8f-0d9e13c2bea6  06-03-2022 13:50
#
#                                 product_id           category customer_type  \
# 7824  bc6187a9-d508-482b-9ca6-590d1cc7524f  cleaning products         basic
# 7825  707e4237-191c-4cc9-85af-383a6c1cb2ab  cleaning products      standard
# 7826  a9325c1a-2715-41df-b7f4-3078fa5ecd97  cleaning products         basic
# 7827  707e4237-191c-4cc9-85af-383a6c1cb2ab  cleaning products         basic
# 7828  d6ccd088-11be-4c25-aa1f-ea87c01a04db  cleaning products    non-member
#
#       unit_price  quantity  total payment_type
# ...

# %%
data.describe ()
# Out:
#         Unnamed: 0   unit_price     quantity        total
# count  7829.000000  7829.000000  7829.000000  7829.000000
# mean   3914.000000     7.819480     2.501597    19.709905
# std    2260.181962     5.388088     1.122722    17.446680
# min       0.000000     0.190000     1.000000     0.190000
# 25%    1957.000000     3.990000     1.000000     6.570000
# 50%    3914.000000     7.190000     3.000000    14.970000
# 75%    5871.000000    11.190000     4.000000    28.470000
# max    7828.000000    23.990000     4.000000    95.960000

# %% [markdown]
# # Visualize The data

# %%
plt.figure(figsize = (15,10))
plt.hist(data['customer_type'])
plt.title('Customer hist')
plt.show()

# %%
plt.figure(figsize = (15,10))
sns.countplot(data = data, x = 'category',hue = 'quantity')
plt.show()

# %%
plt.figure(figsize = (15,10))
sns.scatterplot(data = data,x = 'customer_type',y = 'category')
plt.show()

# %%
plt.figure(figsize = (15,10))
sns.set(style = 'whitegrid')

sns.histplot(data['category'],bins = 10)
plt.show()

# %%
plt.figure(figsize = (15,4))
sns.set(style ='darkgrid')
sns.histplot(data['customer_type'],bins = 3)
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.set(style = 'whitegrid')
sns.pairplot(data = data,hue = 'payment_type')
plt.show()

# %%
plt.figure(figsize = (15,10))
sns.set(style = 'whitegrid')
sns.pairplot(data = data,hue = 'category')
plt.show()

# %%
plt.figure(figsize = (10,3))
sns.heatmap(data.corr(),annot = False)
plt.show()
# Out:
# <ipython-input-36-7dc8df3ce837>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot = False)

# %%
sns.set(style = 'whitegrid')
sns.violinplot(x = 'quantity',y = 'total',data =data)
plt.show()

# %% [markdown]
# # import corresponding  Machine learning libraries

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler

# %%
# x = data[	'customer_type',	'unit_price','quantity',	'total']
x = data[[ 'unit_price', 'quantity']]
y = data['payment_type']

# %% [markdown]
# # Train test and split the data

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.5,random_state= 40)

# %% [markdown]
# # Model Classification
#
# ---

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay
import pandas as pd

# %% [markdown]
# # ABS Classifier Model

# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import AdaBoostClassifier
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.5,random_state= 40)


data = pd.read_csv("/content/sample_sales_data.csv")
abc = AdaBoostClassifier(random_state=1)
model = abc.fit(x_train,y_train)

prediction = model.predict(x_test)
print("AdaBoost Classifier Model Accuracy:", accuracy_score(y_test, prediction))
# Out:
# AdaBoost Classifier Model Accuracy: 0.2549169859514687

# %% [markdown]
# #confuse Matrix Accuracy

# %%
from sklearn.metrics import accuracy_score, classification_report
from sklearn import metrics

confusion_matrix1=metrics.confusion_matrix(y_test, prediction)
confusion_matrix1
# Out:
# array([[378, 301, 212, 124],
#        [335, 295, 229, 113],
#        [310, 306, 202, 111],
#        [349, 329, 198, 123]])

# %%
print('the accuracy of the ',accuracy_score(y_test, prediction))

from sklearn.metrics import ConfusionMatrixDisplay
fig, ax = plt.subplots(figsize=(10,6), dpi=80)
display = ConfusionMatrixDisplay(confusion_matrix1)
ax.set(title='x')
display.plot(ax=ax)
# Out:
# the accuracy of the  0.2549169859514687

# %% [markdown]
# # Random Forest Model

# %%
x = data[['unit_price']]
y = data['payment_type']

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)


model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)


y_pred = model.predict(X_test)


accuracy = accuracy_score(y_test, y_pred)
print('accuracy of teh model:',accuracy)
# Out:
# accuracy of teh model: 0.2503192848020434

# %% [markdown]
# # Conclusion

# %% [markdown]
# Here I got the accuracy of the model is 25% this quite low accuracy. But as per my knowledge i tried my Best to predict the accuracy of the Model.
#
# Hope You like my Work.
